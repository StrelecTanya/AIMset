# %%
# !wget https://ftp.1000genomes.ebi.ac.uk/vol1/ftp/release/20130502/integrated_call_samples_v3.20130502.ALL.panel
# Out:
# --2024-06-26 05:42:26--  https://ftp.1000genomes.ebi.ac.uk/vol1/ftp/release/20130502/integrated_call_samples_v3.20130502.ALL.panel
# Resolving ftp.1000genomes.ebi.ac.uk (ftp.1000genomes.ebi.ac.uk)... 193.62.193.167
# Connecting to ftp.1000genomes.ebi.ac.uk (ftp.1000genomes.ebi.ac.uk)|193.62.193.167|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55156 (54K)
# Saving to: ‘integrated_call_samples_v3.20130502.ALL.panel.1’
#
# integrated_call_sam 100%[===================>]  53.86K   279KB/s    in 0.2s
#
# 2024-06-26 05:42:27 (279 KB/s) - ‘integrated_call_samples_v3.20130502.ALL.panel.1’ saved [55156/55156]

# %%
# !wget -nH --cut-dirs=4 -r -p -e robots=off -A 'ALL.*' https://ftp.1000genomes.ebi.ac.uk/vol1/ftp/release/20130502/
# Out:
# --2024-06-26 05:39:20--  https://ftp.1000genomes.ebi.ac.uk/vol1/ftp/release/20130502/
# Resolving ftp.1000genomes.ebi.ac.uk (ftp.1000genomes.ebi.ac.uk)... 193.62.193.167
# Connecting to ftp.1000genomes.ebi.ac.uk (ftp.1000genomes.ebi.ac.uk)|193.62.193.167|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html.tmp’
#
# index.html.tmp          [ <=>                ]  19.90K  --.-KB/s    in 0.1s
#
# 2024-06-26 05:39:21 (208 KB/s) - ‘index.html.tmp’ saved [20382]
#
# Removing index.html.tmp since it should be rejected.
#
# --2024-06-26 05:39:21--  https://ftp.1000genomes.ebi.ac.uk/vol1/ftp/release/20130502/?C=N;O=D
# Reusing existing connection to ftp.1000genomes.ebi.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?C=N;O=D.tmp’
#
# index.html?C=N;O=D.     [ <=>                ]  19.90K  --.-KB/s    in 0.03s
#
# 2024-06-26 05:39:21 (642 KB/s) - ‘index.html?C=N;O=D.tmp’ saved [20382]
#
# Removing index.html?C=N;O=D.tmp since it should be rejected.
#
# --2024-06-26 05:39:21--  https://ftp.1000genomes.ebi.ac.uk/vol1/ftp/release/20130502/?C=M;O=A
# Reusing existing connection to ftp.1000genomes.ebi.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?C=M;O=A.tmp’
#
# index.html?C=M;O=A.     [ <=>                ]  19.90K  --.-KB/s    in 0.02s
#
# 2024-06-26 05:39:21 (1010 KB/s) - ‘index.html?C=M;O=A.tmp’ saved [20382]
#
# Removing index.html?C=M;O=A.tmp since it should be rejected.
#
# --2024-06-26 05:39:21--  https://ftp.1000genomes.ebi.ac.uk/vol1/ftp/release/20130502/?C=S;O=A
# Reusing existing connection to ftp.1000genomes.ebi.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?C=S;O=A.tmp’
#
# index.html?C=S;O=A.     [ <=>                ]  19.90K  --.-KB/s    in 0.03s
#
# 2024-06-26 05:39:21 (761 KB/s) - ‘index.html?C=S;O=A.tmp’ saved [20382]
#
# Removing index.html?C=S;O=A.tmp since it should be rejected.
#
# --2024-06-26 05:39:21--  https://ftp.1000genomes.ebi.ac.uk/vol1/ftp/release/20130502/?C=D;O=A
# Reusing existing connection to ftp.1000genomes.ebi.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?C=D;O=A.tmp’
#
# index.html?C=D;O=A.     [ <=>                ]  19.90K  --.-KB/s    in 0.02s
#
# 2024-06-26 05:39:21 (1004 KB/s) - ‘index.html?C=D;O=A.tmp’ saved [20382]
#
# Removing index.html?C=D;O=A.tmp since it should be rejected.
#
# --2024-06-26 05:39:21--  https://ftp.1000genomes.ebi.ac.uk/vol1/ftp/release/
# Reusing existing connection to ftp.1000genomes.ebi.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2665 (2.6K) [text/html]
# Saving to: ‘index.html.tmp’
#
# index.html.tmp      100%[===================>]   2.60K  --.-KB/s    in 0s
#
# 2024-06-26 05:39:21 (697 MB/s) - ‘index.html.tmp’ saved [2665/2665]
#
# Removing index.html.tmp since it should be rejected.
#
# --2024-06-26 05:39:21--  https://ftp.1000genomes.ebi.ac.uk/vol1/ftp/release/20130502/ALL.chr1.phase3_shapeit2_mvncall_integrated_v5b.20130502.genotypes.vcf.gz
# Reusing existing connection to ftp.1000genomes.ebi.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1165011543 (1.1G) [application/x-gzip]
# Saving to: ‘ALL.chr1.phase3_shapeit2_mvncall_integrated_v5b.20130502.genotypes.vcf.gz’
#
# ALL.chr1.phase3_sha 100%[===================>]   1.08G  39.7MB/s    in 33s
#
# 2024-06-26 05:39:55 (33.8 MB/s) - ‘ALL.chr1.phase3_shapeit2_mvncall_integrated_v5b.20130502.genotypes.vcf.gz’ saved [1165011543/1165011543]
#
# --2024-06-26 05:39:55--  https://ftp.1000genomes.ebi.ac.uk/vol1/ftp/release/20130502/ALL.chr1.phase3_shapeit2_mvncall_integrated_v5b.20130502.genotypes.vcf.gz.tbi
# Reusing existing connection to ftp.1000genomes.ebi.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 224369 (219K) [application/x-gzip]
# Saving to: ‘ALL.chr1.phase3_shapeit2_mvncall_integrated_v5b.20130502.genotypes.vcf.gz.tbi’
#
# ALL.chr1.phase3_sha 100%[===================>] 219.11K  --.-KB/s    in 0.001s
#
# 2024-06-26 05:39:55 (181 MB/s) - ‘ALL.chr1.phase3_shapeit2_mvncall_integrated_v5b.20130502.genotypes.vcf.gz.tbi’ saved [224369/224369]
#
# --2024-06-26 05:39:55--  https://ftp.1000genomes.ebi.ac.uk/vol1/ftp/release/20130502/ALL.chr2.phase3_shapeit2_mvncall_integrated_v5b.20130502.genotypes.vcf.gz
# Reusing existing connection to ftp.1000genomes.ebi.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1255861869 (1.2G) [application/x-gzip]
# Saving to: ‘ALL.chr2.phase3_shapeit2_mvncall_integrated_v5b.20130502.genotypes.vcf.gz’
#
# es.vcf.gz            50%[=========>          ] 607.10M  38.2MB/s    eta 16s    ^C

# %% [markdown]
# Практическая работа. Работа с библиотекой.

# %%
pip install hail
# Out:
# Requirement already satisfied: hail in /usr/local/lib/python3.10/dist-packages (0.2.131)
# Requirement already satisfied: aiodns<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from hail) (2.0.0)
# Requirement already satisfied: aiohttp<4,>=3.9 in /usr/local/lib/python3.10/dist-packages (from hail) (3.9.5)
# Requirement already satisfied: azure-identity<2,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from hail) (1.17.1)
# Requirement already satisfied: azure-mgmt-storage==20.1.0 in /usr/local/lib/python3.10/dist-packages (from hail) (20.1.0)
# Requirement already satisfied: azure-storage-blob<13,>=12.11.0 in /usr/local/lib/python3.10/dist-packages (from hail) (12.20.0)
# Requirement already satisfied: boto3<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from hail) (1.34.133)
# Requirement already satisfied: botocore<2.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from hail) (1.34.133)
# Requirement already satisfied: dill<0.4,>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from hail) (0.3.8)
# Requirement already satisfied: frozenlist<2,>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from hail) (1.4.1)
# Requirement already satisfied: google-auth<3,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from hail) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<1,>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from hail) (0.8.0)
# Requirement already satisfied: humanize<2,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from hail) (1.1.0)
# Requirement already satisfied: janus<1.1,>=0.6 in /usr/local/lib/python3.10/dist-packages (from hail) (1.0.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from hail) (1.6.0)
# Requirement already satisfied: orjson<4,>=3.9.15 in /usr/local/lib/python3.10/dist-packages (from hail) (3.10.5)
# Requirement already satisfied: rich<13,>=12.6.0 in /usr/local/lib/python3.10/dist-packages (from hail) (12.6.0)
# Requirement already satisfied: typer<1,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from hail) (0.12.3)
# Requirement already satisfied: python-json-logger<3,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from hail) (2.0.7)
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from hail) (6.0.1)
# Requirement already satisfied: sortedcontainers<3,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from hail) (2.4.0)
# Requirement already satisfied: tabulate<1,>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from hail) (0.9.0)
# Requirement already satisfied: jproperties<3,>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from hail) (2.1.1)
# Requirement already satisfied: avro<1.12,>=1.10 in /usr/local/lib/python3.10/dist-packages (from hail) (1.11.3)
# Requirement already satisfied: bokeh<3.4,>=3 in /usr/local/lib/python3.10/dist-packages (from hail) (3.3.4)
# Requirement already satisfied: decorator<5 in /usr/local/lib/python3.10/dist-packages (from hail) (4.4.2)
# Requirement already satisfied: Deprecated<1.3,>=1.2.10 in /usr/local/lib/python3.10/dist-packages (from hail) (1.2.14)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from hail) (1.25.2)
# Requirement already satisfied: pandas<3,>=2 in /usr/local/lib/python3.10/dist-packages (from hail) (2.0.3)
# Requirement already satisfied: parsimonious<1 in /usr/local/lib/python3.10/dist-packages (from hail) (0.10.0)
# Requirement already satisfied: plotly<6,>=5.18.0 in /usr/local/lib/python3.10/dist-packages (from hail) (5.22.0)
# Requirement already satisfied: protobuf==3.20.2 in /usr/local/lib/python3.10/dist-packages (from hail) (3.20.2)
# Requirement already satisfied: pyspark<3.6,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from hail) (3.5.1)
# Requirement already satisfied: requests<3,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from hail) (2.31.0)
# Requirement already satisfied: scipy<1.12,>1.2 in /usr/local/lib/python3.10/dist-packages (from hail) (1.11.4)
# Requirement already satisfied: uvloop<1,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from hail) (0.19.0)
# Requirement already satisfied: msrest>=0.6.21 in /usr/local/lib/python3.10/dist-packages (from azure-mgmt-storage==20.1.0->hail) (0.7.1)
# Requirement already satisfied: azure-common~=1.1 in /usr/local/lib/python3.10/dist-packages (from azure-mgmt-storage==20.1.0->hail) (1.1.28)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from azure-mgmt-storage==20.1.0->hail) (1.4.0)
# Requirement already satisfied: pycares>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from aiodns<3,>=2.0.0->hail) (4.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.9->hail) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.9->hail) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.9->hail) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.9->hail) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.9->hail) (4.0.3)
# Requirement already satisfied: azure-core>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from azure-identity<2,>=1.6.0->hail) (1.30.2)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.10/dist-packages (from azure-identity<2,>=1.6.0->hail) (42.0.8)
# Requirement already satisfied: msal>=1.24.0 in /usr/local/lib/python3.10/dist-packages (from azure-identity<2,>=1.6.0->hail) (1.29.0)
# Requirement already satisfied: msal-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from azure-identity<2,>=1.6.0->hail) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from azure-identity<2,>=1.6.0->hail) (4.12.2)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob<13,>=12.11.0->hail) (0.6.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.4,>=3->hail) (3.1.4)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.4,>=3->hail) (1.2.1)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.4,>=3->hail) (24.1)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.4,>=3->hail) (9.4.0)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.4,>=3->hail) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.4,>=3->hail) (2024.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3<2.0,>=1.17->hail) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from boto3<2.0,>=1.17->hail) (0.10.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<2.0,>=1.20->hail) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<2.0,>=1.20->hail) (2.0.7)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated<1.3,>=1.2.10->hail) (1.14.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=2.14.1->hail) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=2.14.1->hail) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=2.14.1->hail) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1,>=0.5.2->hail) (1.3.1)
# Requirement already satisfied: six~=1.13 in /usr/local/lib/python3.10/dist-packages (from jproperties<3,>=2.1.1->hail) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=2->hail) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=2->hail) (2024.1)
# Requirement already satisfied: regex>=2022.3.15 in /usr/local/lib/python3.10/dist-packages (from parsimonious<1->hail) (2024.5.15)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6,>=5.18.0->hail) (8.4.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark<3.6,>=3.5.0->hail) (0.10.9.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.31.0->hail) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.31.0->hail) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.31.0->hail) (2024.6.2)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from rich<13,>=12.6.0->hail) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from rich<13,>=12.6.0->hail) (2.16.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1,>=0.9.0->hail) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1,>=0.9.0->hail) (1.5.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.5->azure-identity<2,>=1.6.0->hail) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh<3.4,>=3->hail) (2.1.5)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in /usr/lib/python3/dist-packages (from msal>=1.24.0->azure-identity<2,>=1.6.0->hail) (2.3.0)
# Requirement already satisfied: portalocker<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from msal-extensions>=0.3.0->azure-identity<2,>=1.6.0->hail) (2.10.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=2.14.1->hail) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1,>=0.5.2->hail) (3.2.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2,>=1.6.0->hail) (2.22)

# %%
import hail as hl
from hail.plot import show
from pprint import pprint

# %% [markdown]
# Prepare - удаляем группу AMR (смешанные американцы) и создаем тестовую и обучающую выборки

# %%
# !grep -E 'AFR|EUR|SAS|EAS' annotation.txt > annotation_noAMR.txt
# Out:
# grep: annotation.txt: No such file or directory

# %% [markdown]
# STEP0 - отбираем только би-аллельные SNP и убирает инделы

# %%
chr1 = hl.import_vcf('ALL.chr1.phase3_shapeit2_mvncall_integrated_v5b.20130502.genotypes.vcf.gz', force_bgz=True)
# Out:
# Initializing Hail with default parameters...
# Running on Apache Spark version 3.5.1
# SparkUI available at http://d41f68cc0b17:4040
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.131-11d9b2ff89da
# LOGGING: writing to /content/hail-20240626-0543-0.2.131-11d9b2ff89da.log

# %%
#only bi-allelic SNP
chr1 = chr1.filter_rows(hl.len(chr1.alleles) == 2)
#remove indels
chr1 = chr1.filter_rows(hl.is_snp(chr1.alleles[0], chr1.alleles[1]))

# %%
#Получаем тестовую и обучающую выборку
import pandas as pd
import numpy as np
import os
#Обозначение переменных
testindsperdeme = 100
demes = 5
filenameInds = "integrated_call_samples_v3.20130502.ALL.panel"
filenameIndsTest = "annotationTest.txt"
filenameIndsTraining = "annotationTraining.txt"


size = [testindsperdeme for i in range(demes)]
a = pd.read_csv(filenameInds, sep='\t' )
pops = np.sort(np.unique(a.iloc[:, 2]))
inds = a.iloc[:, [0, 2]]
noinds = np.zeros(len(pops), dtype=int)
testset, trainingset = [], []

for i in range(len(pops)):
    indslocal = inds[inds.iloc[:, 1] == pops[i]].iloc[:, 0]
    noinds[i] = np.sum(inds.iloc[:, 1] == pops[i])
    s = np.random.choice(noinds[i], size[i], replace=False)
    testset.extend(indslocal.iloc[s])
    trainingset.extend(indslocal.iloc[np.setdiff1d(np.arange(noinds[i]), s)])

#Создаем пустые файлы с заголовком
os.system(f" head -n 1 {filenameInds} > {filenameIndsTest}")
os.system(f" head -n 1 {filenameInds} > {filenameIndsTraining}")

#Создаем файлы с аннотацией образцов для обучающего и тестового образца по отобранным именам
for test_id in testset:
    os.system(f"grep -w {test_id} {filenameInds} >> {filenameIndsTest}")

for train_id in trainingset:
    os.system(f"grep -w {train_id} {filenameInds} >> {filenameIndsTraining}")

# %% [markdown]
# STEP1 - считаем частоты SNP

# %%
table = hl.import_table("integrated_call_samples_v3.20130502.ALL.panel").key_by("sample")
mt = chr1

# объединяем данные из аннотации с данными из vcf файла
mt = mt.annotate_cols(pheno=table[mt.s])

#Список популяций в файле
pops = list(table.aggregate(hl.agg.collect_as_set(table.super_pop)))

# Инициализация таблицы первой популяцией
mt_pop = mt.filter_cols(mt.pheno.super_pop == pops[0])
mt_pop = hl.variant_qc(mt_pop)
mt_pop = mt_pop.annotate_rows(alt = mt_pop.variant_qc.AF[1])
freq_table = mt_pop.rows().select('alt').rename({"alt": f'{pops[0]}'})

# Цикл по оставшимся популяциям
for pop in pops[1:]:
  mt_pop = mt.filter_cols(mt.pheno.super_pop == pop)
  mt_pop = hl.variant_qc(mt_pop)
  mt_pop = mt_pop.annotate_rows(alt = mt_pop.variant_qc.AF[1])
  pop_freq = mt_pop.rows().select('alt').rename({"alt": f'{pop}'})

  # Объединяем таблицы
  freq_table = freq_table.join(pop_freq)

# %% [markdown]
# STEP2 - фильтрация SNP по информативности

# %%
#Задаем уровень информативности, при котором мы оставляем SNP
informativenessBound = 0.9
#Вводим дополнительные функции для подсчета информативности
def xlogx2(x):
    z = xlogx(x) + xlogx(1 - x)
    return z

def xlogx(x):
    z = hl.if_else(x == 0, 0, x * hl.log(x))
    return z
#Считаем количесвто строк в файле
nss = freq_table.count()
#Считаем средние
freq_table = freq_table.annotate(
    mean_row=(freq_table.AFR + freq_table.SAS + freq_table.EUR + freq_table.AMR + freq_table.EAS) / len(pops)
)
freq_table = freq_table.annotate(
    mean_row_log=(xlogx2(freq_table.AFR) + xlogx2(freq_table.SAS) + xlogx2(freq_table.EUR) + xlogx2(freq_table.AMR) + xlogx2(freq_table.EAS)) / len(pops)
)
#Считаем информативность
freq_table = freq_table.annotate(info= -xlogx2(freq_table.mean_row) + freq_table.mean_row_log)
#Фильтруем таблицу по информативности (в порядке убывания) и отбираем 10% самых информативных SNP
informativenessQuantile = freq_table.order_by(hl.desc(freq_table.info)).head(hl.eval(hl.int32(hl.floor((1 - informativenessBound)* nss))))
#Создаем новый vcf-файл с отобранными SNP по информативности
informativenessQuantile = informativenessQuantile.key_by("locus")
mt = chr1.filter_rows(hl.is_defined(informativenessQuantile[chr1.locus]))
#Сохраняем файл
hl.export_vcf(mt, 'tmp/filter_chr1.vcf.bgz')

# %% [markdown]
# STEP3 - делим имеющийся файл на маленькие

# %%
mt = hl.import_vcf('tmp/filter_chr1.vcf.bgz')
stepsize = 10000
# Вычисляем количество сегментов и преобразуем в список
segments = hl.range(0, hl.int32((mt.count_rows() - 1) // stepsize + 1)).collect()
# Добавляем столбец с номером строки
mt = mt.annotate_rows(row_index=hl.scan.count())

# Фильтруем строки по номеру

# Цикл по сегментам
for j in segments[0]:
    start = j * stepsize
    end = hl.eval(min((j + 1) * stepsize, mt.count_rows()))
    # Фильтруем строки по номеру
    segment_mt = mt.filter_rows((mt.row.row_index >= start) & (mt.row.row_index < end))
    hl.export_vcf(segment_mt, f"tmp/chr_segment{j}.vcf.bgz")

# %% [markdown]
# STEP4 - считаем кол-во строк в новом vcf файле

# %%
nss = hl.eval(chr.count()[0])

# %%
#STEP5
def genotype_to_number(gt):
    z = hl.case().when(gt.is_het(), 1).when(gt.is_hom_ref(), 0).when(gt.is_hom_var(), 2).or_missing()
    return z
for j in segments[0]:
    mt = hl.import_vcf(f"tmp/chr_segment{j}.vcf.bgz")
    mt = mt.annotate_entries(GT=genotype_to_number(mt.GT))
    mt.write(f'tmp/chr_segment{j}.mt', overwrite=True)

# %%
chr = chr1.head(200)

# %%
def genotype_to_number(gt):
    z = hl.case().when(gt.is_het(), 1).when(gt.is_hom_ref(), 0).when(gt.is_hom_var(), 2).or_missing()
    return z

# %%
mt = chr.annotate_entries(GT=genotype_to_number(chr.GT))
mt.write('chr.mt', overwrite=True)
# Out:
# 2024-06-26 05:44:34.832 Hail: INFO: scanning VCF for sortedness...
# 2024-06-26 05:47:21.919 Hail: INFO: Coerced prefix-sorted VCF, requiring additional sorting within data partitions on each query.
# 2024-06-26 05:47:30.830 Hail: INFO: wrote matrix table with 200 rows and 2504 columns in 1 partition to chr.mt

# %%
#STEP6
a = hl.import_table("annotationTraining.txt").select("sample","super_pop")
#Создаем список с именами все анализируемых vcf файлов
#findAIMs
method = "naiveBayes"
error_type="misclassification"
diploid = True
outfile = "AIMs"
#Количесвто AIM, которое мы хотим получить в итоге
numAIM = 10
#Частота встречаемости популяций
samples_in_deme = a.aggregate(hl.agg.counter(a.super_pop))
#Создаем пустую таблицу для хоанения информативных маркеров
sampleAIMs = hl.Table.parallelize([])
#Считаем количесвто столбцов в таблице sampleAIMs
no = hl.if_else(len(sampleAIMs.row) == 0, 0, len(sampleAIMs.row))
min_error = 1000
# Out:
# 2024-06-26 05:47:42.930 Hail: WARN: Name collision: field 'sample' already in object dict.
#   This field must be referenced with __getitem__ syntax: obj['sample']
# 2024-06-26 05:47:42.941 Hail: INFO: Reading table without type imputation
#   Loading field 'sample' as type str (not specified)
#   Loading field 'pop' as type str (not specified)
#   Loading field 'super_pop' as type str (not specified)
#   Loading field 'gender' as type str (not specified)

# %%
#Внутреннее содержимое функции getfreqs
#Создаем список всех локусов
locus_list = mt.locus.collect()
#Импортируем необходимые файлы
table_annotation = hl.import_table("annotationTraining.txt").key_by("sample")
mt = chr

#объединяем данные из аннотации с данными из vcf файла
mt = mt.annotate_cols(pheno=table_annotation[mt.s])

#Список популяций в файле
pops = list(table_annotation.aggregate(hl.agg.collect_as_set(table_annotation.super_pop)))

# Инициализация таблицы первой популяцией
mt_pop = mt.filter_cols(mt.pheno.super_pop == pops[0])
mt_pop = hl.variant_qc(mt_pop)
mt_pop = mt_pop.annotate_rows(alt = mt_pop.variant_qc.AC[1]).key_rows_by("locus")
freq_list = mt_pop.alt.collect()
locus_freq_table = hl.Table.parallelize(
    [{"locus": locus, "frequency": freq} for locus, freq in zip(locus_list, freq_list)],
    hl.tstruct(locus=hl.tlocus("GRCh37"), frequency=hl.tint32),
).rename({"frequency": f'{pops[0]}'})
table = locus_freq_table.key_by("locus")
# Цикл по оставшимся популяциям
for pop in pops[1:]:
  mt_pop = mt.filter_cols(mt.pheno.super_pop == pop)
  mt_pop = hl.variant_qc(mt_pop)
  mt_pop = mt_pop.annotate_rows(alt = mt_pop.variant_qc.AC[1]).key_rows_by("locus")
  freq_list = mt_pop.alt.collect()
  locus_freq_table = hl.Table.parallelize(
    [{"locus": locus, "frequency": freq} for locus, freq in zip(locus_list, freq_list)],
    hl.tstruct(locus=hl.tlocus("GRCh37"), frequency=hl.tint32)).rename({"frequency": f'{pop}'}).key_by("locus")
  table = table.join(locus_freq_table, how="left")
# Out:
# 2024-06-26 05:48:51.475 Hail: INFO: Reading table without type imputation
#   Loading field 'sample' as type str (not specified)
#   Loading field 'pop' as type str (not specified)
#   Loading field 'super_pop' as type str (not specified)
#   Loading field 'gender' as type str (not specified)

# %%
#Считаем количесвто групп
demes = len(table.row) - 1

# %%
#Реализуем функцию find.next.AIM

# %%
import re

# %%
sample_test = hl.read_matrix_table('chr.mt').head(20)
sample_names = [(re.search(r"Struct\(sample='(.*?)'\)", str(i)).group(1)) for i in table_annotation.key_by().select("sample").collect()]

# %%
sample_test.count_rows()
# Out:
# 20

# %%
error = []

for i in range(sample_test.count_rows()):
  snp_num = i
  e = App_test_error(sample_test, table, sample_names, snp_num, table_annotation)
  error.append(e)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# 2024-06-26 08:03:51.555 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:03:52.291 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:03:52.858 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:03:53.427 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:03:53.892 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:03:55.636 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:03:56.258 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:03:56.867 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:03:57.385 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:03:57.958 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:03.522 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:04.184 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:04.667 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:05.055 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:05.557 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:07.919 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:08.465 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:08.981 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:09.602 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:10.277 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:14.443 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:15.092 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:15.687 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:16.347 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:16.855 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:18.727 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:19.328 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:19.974 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:20.612 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:21.237 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:24.849 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:25.460 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:26.314 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:26.735 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:27.310 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:30.193 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:30.869 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:31.488 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:32.124 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:32.776 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:36.369 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:37.214 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:38.042 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:38.630 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:39.312 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:41.148 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:41.539 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:42.173 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:42.803 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:43.399 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:45.668 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:46.223 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:47.928 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:48.682 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:49.349 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:51.331 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:51.893 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:52.206 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:52.589 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:53.217 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:57.609 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:58.979 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:59.425 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:04:59.785 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:00.094 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:01.001 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:01.279 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:01.613 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:01.928 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:02.277 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:03.490 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:04.659 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:05.115 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:05.566 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:05.972 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:07.012 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:07.224 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:07.505 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:07.885 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:08.342 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:10.167 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:10.734 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:12.491 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:13.165 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:14.009 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:17.213 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:17.826 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:18.435 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:19.042 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:19.581 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:23.429 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:24.068 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:24.681 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:25.238 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:25.738 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:27.884 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:28.539 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:29.154 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:29.769 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:30.400 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:33.148 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:33.551 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:33.904 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:34.198 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:34.395 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:35.397 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:35.695 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:36.031 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:36.343 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:36.639 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:39.517 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:39.784 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:40.040 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:40.349 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:40.698 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:41.829 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:42.292 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:42.813 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:44.599 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:45.275 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:47.381 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:47.761 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:48.108 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:48.585 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:49.147 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:51.277 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:51.865 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:52.464 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:53.066 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:53.607 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:57.316 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:57.877 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:58.396 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:58.743 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:05:59.266 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:03.299 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:05.025 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:05.424 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:05.920 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:06.246 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:07.228 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:07.592 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:07.957 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:08.320 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:08.635 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:09.776 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:10.724 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:11.116 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:11.479 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:11.877 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:13.169 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:13.554 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:13.963 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:14.408 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:14.756 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:17.873 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:18.641 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:19.313 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:19.814 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:20.429 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:24.008 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:24.623 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:25.206 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:25.829 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:26.332 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:30.192 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:30.724 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:31.327 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:31.958 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:32.317 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:34.352 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:34.919 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:35.540 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:36.142 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:36.713 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:40.814 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:41.396 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:41.722 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:42.035 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:42.269 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:43.349 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:43.673 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:44.058 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:44.390 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:44.719 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:47.384 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:47.579 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:47.816 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:48.100 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:48.457 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:49.607 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:49.921 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:50.241 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:51.212 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:51.750 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:53.741 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:54.123 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:54.686 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:55.194 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:55.856 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:58.070 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:06:58.650 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:00.705 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:01.598 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:02.322 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:04.538 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:04.900 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:05.480 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:06.127 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:06.876 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:12.209 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:12.941 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:13.693 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:14.320 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:14.915 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:16.394 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:16.698 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:16.994 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:17.360 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:17.694 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:18.829 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:19.758 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:20.238 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:20.681 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:20.994 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:21.954 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:22.251 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:22.570 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:23.010 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:23.408 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:24.734 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:25.948 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:26.481 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:27.152 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:27.651 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:30.585 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:31.238 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:31.875 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:32.374 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:32.794 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:34.910 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:36.773 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:37.466 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:38.075 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:38.669 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:40.492 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:41.033 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:41.675 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:42.283 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:42.831 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:45.019 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:45.694 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:47.749 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:48.702 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:49.314 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:51.125 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:51.363 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:51.638 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:51.950 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:52.335 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:55.025 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:55.467 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:55.931 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:56.296 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:56.614 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:57.544 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:57.843 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:58.147 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:58.480 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:07:58.809 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:00.005 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:01.186 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:01.930 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:02.646 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:03.252 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:05.082 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:05.568 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:06.173 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:06.849 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:07.441 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:09.610 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:10.251 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:12.280 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:13.009 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:13.728 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:17.535 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:18.106 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:18.662 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:19.230 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:19.823 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:23.359 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:24.381 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:25.082 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:25.653 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:26.286 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:28.245 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:28.711 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:29.349 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:30.038 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:30.799 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:33.059 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:34.998 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:35.827 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:36.658 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:37.383 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:39.471 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:39.924 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:40.605 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:41.274 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:41.952 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:47.311 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:47.687 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:47.967 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:48.320 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:48.607 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:49.847 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:50.174 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:50.519 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:50.872 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:51.278 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:53.137 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:53.429 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:53.741 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:54.082 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:54.341 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:55.351 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:55.777 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:56.293 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:56.865 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:08:57.392 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:00.799 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:01.464 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:02.026 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:02.604 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:03.122 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:06.256 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:06.889 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:07.506 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:08.112 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:08.754 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:12.894 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:13.587 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:14.203 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:14.816 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:15.183 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:17.145 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:17.642 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:18.343 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:18.930 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:19.476 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:21.733 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:22.177 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:22.557 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:22.893 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:23.152 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:24.462 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:24.761 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:25.079 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:25.391 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:25.689 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:28.567 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:28.882 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:29.226 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:29.535 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:29.855 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:31.537 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:32.061 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:33.697 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:34.325 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:34.999 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:37.037 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:37.415 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:37.898 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:38.388 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:38.934 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:41.046 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:41.643 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:42.315 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:44.222 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:44.931 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:47.171 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:47.699 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:48.094 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:48.553 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:49.101 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:54.638 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:55.379 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:55.962 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:56.299 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:56.602 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:57.496 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:57.764 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:58.082 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:58.395 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:58.729 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:09:59.843 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:00.802 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:01.211 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:01.620 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:01.968 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:02.938 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:03.173 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:03.443 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:03.746 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:04.075 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:05.236 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:05.562 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:07.007 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:07.750 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:08.379 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:11.630 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:12.263 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:12.871 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:13.509 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:14.121 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:17.481 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:18.156 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:18.634 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:19.204 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:19.673 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:21.114 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:21.720 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:22.286 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:22.828 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:23.402 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:26.628 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:27.307 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:28.041 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:28.538 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:29.151 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:30.981 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:31.352 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:31.633 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:31.924 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:32.244 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:34.832 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:35.369 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:35.892 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:36.198 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:36.568 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:37.471 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:37.792 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:38.100 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:38.414 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:38.769 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:40.015 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:41.079 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:41.513 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:41.966 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:42.472 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:44.127 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:44.581 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:45.239 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:45.887 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:46.531 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:48.568 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:50.534 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:51.295 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:52.049 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:52.685 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:55.951 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:56.553 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:57.125 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:57.791 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:10:58.407 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:02.052 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:02.765 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:03.390 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:04.009 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:04.619 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:06.178 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:06.728 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:07.268 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:07.597 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:07.932 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:09.082 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:10.094 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:10.465 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:10.976 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:11.323 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:12.277 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:12.613 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:12.923 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:13.229 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:13.559 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:16.467 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:16.768 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:17.029 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:17.324 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:17.647 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:19.364 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:19.856 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:20.369 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:20.850 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:21.438 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:25.099 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:25.720 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:26.215 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:26.665 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:27.241 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:29.002 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:29.609 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:30.187 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:30.790 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:31.409 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:34.493 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:36.406 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:37.111 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:37.818 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:38.476 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:41.211 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:41.509 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:41.825 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:42.143 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:42.463 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:44.177 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:44.596 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:45.040 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:45.384 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:45.711 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:46.874 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:47.221 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:47.576 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:47.939 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:48.240 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:50.310 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:50.831 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:51.513 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:52.148 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:52.630 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:54.468 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:55.069 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:55.635 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:56.181 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:11:56.798 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:02.315 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:02.770 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:03.321 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:04.014 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:04.660 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:07.073 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:07.771 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:08.469 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:10.359 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:11.265 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:14.202 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:14.756 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:15.197 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:15.824 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:16.390 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:18.681 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:19.278 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:19.916 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:20.669 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:22.590 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:25.150 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:25.818 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:26.362 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:26.863 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:27.535 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:32.290 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:34.164 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:35.058 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:35.731 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:36.195 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:38.164 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:38.781 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:39.384 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:40.067 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:40.744 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:44.111 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:44.975 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:45.916 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:46.480 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:46.934 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:48.686 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:49.205 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:49.772 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:50.410 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:51.065 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:53.406 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:55.315 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:56.005 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:56.759 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:12:57.413 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:00.750 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:01.392 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:02.052 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:02.709 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:03.129 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:04.952 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:05.361 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:05.748 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:06.031 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:06.350 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:07.248 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:07.545 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:07.861 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:08.138 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:08.414 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:09.581 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:10.581 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:11.041 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:11.523 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:11.816 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:12.752 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:13.110 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:13.687 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:14.265 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:14.883 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:20.244 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:20.840 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:21.455 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:21.897 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:22.544 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:24.331 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:24.999 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:25.597 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:26.182 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:26.702 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:30.291 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:31.131 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:31.791 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:32.307 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:32.916 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:34.434 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:35.019 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:35.499 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:36.086 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:36.678 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:41.289 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:41.618 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:41.904 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:42.229 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:42.531 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:44.974 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:45.316 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:45.594 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:45.903 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:46.255 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:47.347 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:47.692 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:49.035 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:49.641 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:50.195 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:51.859 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:52.437 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:53.051 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:53.658 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:54.266 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:56.338 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:56.923 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:57.437 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:13:59.316 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:00.044 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:02.439 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:03.160 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:03.849 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:04.459 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:04.957 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:10.411 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:10.997 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:11.455 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:12.077 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:12.621 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:14.446 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:14.724 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:15.094 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:15.357 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:15.661 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:18.012 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:18.406 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:18.796 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:19.149 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:19.539 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:20.788 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:21.517 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:21.844 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:22.255 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:23.301 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:24.799 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:25.353 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:25.836 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:26.408 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:26.932 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:30.635 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:32.550 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:33.289 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:33.865 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:34.413 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:36.659 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:37.328 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:37.966 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:38.613 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:39.189 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:42.864 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:43.636 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:44.326 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:44.939 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:45.577 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:47.577 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:48.166 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:48.777 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:49.332 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:49.937 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:51.675 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:52.105 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:52.454 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:52.771 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:53.075 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:54.911 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:55.206 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:55.527 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:56.466 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:56.926 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:58.226 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:58.551 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:58.852 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:59.140 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:14:59.488 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:01.113 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:02.649 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:03.345 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:04.052 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:04.645 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:06.589 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:07.202 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:07.663 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:08.406 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:09.059 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:12.520 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:13.193 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:13.938 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:14.484 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:15.088 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:18.957 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:19.594 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:20.200 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:20.802 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:22.657 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:23.825 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:24.134 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:24.446 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:24.767 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:25.055 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:26.117 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:26.426 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:26.715 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:27.653 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:28.082 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:29.342 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:29.614 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:29.945 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:30.296 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:30.625 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:31.677 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:32.601 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:33.026 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:33.616 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:34.283 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:37.786 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:38.404 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:38.991 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:39.595 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:40.235 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:43.864 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:44.519 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:45.147 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:45.718 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:46.228 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:48.311 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:48.884 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:49.512 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:50.172 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:50.840 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:54.660 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:55.039 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:55.356 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:55.697 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:55.981 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:57.019 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:57.346 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:57.636 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:57.949 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:15:58.274 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:02.304 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:02.868 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:03.451 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:03.961 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:04.490 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:06.763 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:07.395 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:07.979 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:09.996 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:10.842 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:13.325 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:13.865 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:14.493 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:15.106 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:15.701 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:18.004 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:18.692 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:19.280 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:21.281 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:22.135 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:24.671 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:25.214 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:25.854 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:26.487 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:27.125 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:32.631 Hail: INFO: Coerced sorted dataset
# 2024-06-26 08:16:33.382 Hail: INFO: Coerced sorted dataset
# ...
# 2024-06-26 10:48:41.848 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:48:42.212 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:48:49.600 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:48:54.423 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:49:01.788 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:49:21.809 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:49:25.589 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:49:30.464 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:49:37.750 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:49:45.307 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:50:15.244 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:50:29.651 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:50:33.295 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:50:37.090 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:50:41.652 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:51:12.851 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:51:20.577 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:51:28.029 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:51:35.703 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:51:43.100 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:51:58.704 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:52:02.518 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:52:06.208 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:52:12.247 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:52:19.548 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:52:34.780 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:52:38.630 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:52:42.428 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:52:42.760 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:52:49.208 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:53:05.594 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:53:06.368 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:53:15.311 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:53:18.965 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:53:25.155 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:53:55.442 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:53:55.899 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:54:02.937 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:54:10.670 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:54:18.064 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:54:31.550 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:54:44.353 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:54:51.335 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:54:59.257 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:55:06.597 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:55:31.299 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:55:38.740 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:55:45.963 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:55:50.994 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:55:54.654 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:56:06.912 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:56:21.036 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:56:21.890 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:56:27.194 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:56:30.786 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:56:56.507 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:57:02.436 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:57:06.255 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:57:09.967 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:57:15.927 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:57:46.488 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:57:53.211 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:58:00.673 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:58:07.792 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:58:08.476 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:58:27.330 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:58:34.311 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:58:34.999 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:58:49.632 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:58:50.378 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:59:13.499 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:59:21.377 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:59:28.724 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:59:36.277 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:59:41.618 Hail: INFO: Coerced sorted dataset
# 2024-06-26 10:59:56.943 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:00:04.881 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:00:12.405 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:00:17.690 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:00:21.277 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:00:47.846 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:00:53.606 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:00:57.494 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:01:01.220 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:01:07.424 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:01:43.458 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:01:51.309 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:01:58.810 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:02:05.177 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:02:05.504 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:02:18.841 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:02:34.010 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:02:34.781 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:02:50.375 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:02:58.071 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:03:33.878 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:03:37.719 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:03:41.959 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:03:48.937 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:03:56.680 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:04:23.602 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:04:31.050 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:04:38.972 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:04:44.973 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:04:48.900 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:05:14.630 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:05:20.824 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:05:24.687 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:05:28.580 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:05:34.149 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:06:04.308 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:06:18.070 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:06:32.980 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:06:40.512 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:06:47.985 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:07:23.765 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:07:27.551 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:07:31.402 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:07:37.868 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:07:45.117 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:08:12.274 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:08:19.619 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:08:26.975 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:08:34.573 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:08:38.412 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:09:09.745 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:09:13.820 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:09:21.449 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:09:22.147 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:09:29.026 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:09:53.061 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:10:03.489 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:10:18.838 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:10:26.337 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:10:34.616 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:11:21.007 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:11:24.866 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:11:29.649 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:11:43.701 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:11:51.017 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:12:12.423 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:12:19.757 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:12:26.885 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:12:35.143 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:12:35.514 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:13:11.273 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:13:15.141 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:13:22.118 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:13:35.786 Hail: INFO: Coerced sorted dataset
# 2024-06-26 11:13:45.821 Hail: INFO: Coerced sorted dataset
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-319be4a2d963> in <cell line: 3>()
#       3 for i in range(sample_test.count_rows()):
#       4   snp_num = i
# ----> 5   e = App_test_error(sample_test, table, sample_names, snp_num, table_annotation)
#       6   error.append(e)
#
# <ipython-input-19-5fd98e5089c7> in App_test_error(sample_test, counts, sample_names, number_of_snp, table)
#      14   """
#      15     #Считаем матрицу вероятностей
# ---> 16     res = prediction_naive_bayes(sample_test, counts, sample_names, number_of_snp)
#      17     # Преобразуем numpy массив в pandas DataFrame
#      18     df = pd.DataFrame(res, columns=pops)
#
# <ipython-input-15-5fdeedb08a3c> in prediction_naive_bayes(sample_test, counts, sample_names, number_of_snp)
#       1 def prediction_naive_bayes(sample_test, counts, sample_names, number_of_snp):
# ----> 2   res = log_prediction_naiveBayes(sample_test, counts, sample_names, number_of_snp)
#       3   # Вычисляем экспоненту для каждого значения в res, вычитая максимальное значение
#       4   res = np.exp(res - np.max(res))
#       5   # Нормализуем каждую строку так, чтобы сумма элементов в строке была равна 1
#
# <ipython-input-14-c0e8700f75fd> in log_prediction_naiveBayes(sample_test, table_with_freq, sample_names, number_of_snp)
#       5     selected_mt = sample_test.filter_cols(sample_test.s == f'{sample_names[j]}').GT.collect()[number_of_snp]
#       6     for k in range(5):
# ----> 7       counts = [int(re.search(r'\d+(\.\d+)?', str(i)).group(0)) for i in table_with_freq.select(f"{pops[k]}").collect()][number_of_snp]
#       8       res[j, :][k] += np.log(1 + counts) * selected_mt + np.log((1 + diploid) * samples_in_deme[pops[k]] - counts + 1) * (1 + diploid - selected_mt)
#       9   else:
#
# <decorator-gen-1343> in collect(self, _localize, _timed)
#
# /usr/local/lib/python3.10/dist-packages/hail/typecheck/check.py in wrapper(__original_func, *args, **kwargs)
#     583     def wrapper(__original_func: Callable[..., T], *args, **kwargs) -> T:
#     584         args_, kwargs_ = check_all(__original_func, args, kwargs, checkers, is_method=is_method)
# --> 585         return __original_func(*args_, **kwargs_)
#     586
#     587     return wrapper
#
# /usr/local/lib/python3.10/dist-packages/hail/table.py in collect(self, _localize, _timed)
#    2815         e = construct_expr(rows_ir, hl.tarray(t.row.dtype))
#    2816         if _localize:
# -> 2817             return Env.backend().execute(e._ir, timed=_timed)
#    2818         else:
#    2819             return e
#
# /usr/local/lib/python3.10/dist-packages/hail/backend/spark_backend.py in execute(self, ir, timed)
#     216     def execute(self, ir: BaseIR, timed: bool = False) -> Any:
#     217         try:
# --> 218             return super().execute(ir, timed)
#     219         except Exception as err:
#     220             if self._copy_log_on_error:
#
# /usr/local/lib/python3.10/dist-packages/hail/backend/backend.py in execute(self, ir, timed)
#     176         payload = ExecutePayload(self._render_ir(ir), '{"name":"StreamBufferSpec"}', timed)
#     177         try:
# --> 178             result, timings = self._rpc(ActionTag.EXECUTE, payload)
#     179         except FatalError as e:
#     180             raise e.maybe_user_error(ir) from None
#
# /usr/local/lib/python3.10/dist-packages/hail/backend/py4j_backend.py in _rpc(self, action, payload)
#     216         path = action_routes[action]
#     217         port = self._backend_server_port
# --> 218         resp = self._requests_session.post(f'http://localhost:{port}{path}', data=data)
#     219         if resp.status_code >= 400:
#     220             error_json = orjson.loads(resp.content)
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     635         """
#     636
# --> 637         return self.request("POST", url, data=data, json=json, **kwargs)
#     638
#     639     def put(self, url, data=None, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#нормальный log.prediction naive bayes
def log_prediction_naiveBayes(sample_test, table_with_freq, sample_names, number_of_snp):
  res = np.zeros((len(sample_names), 5))
  for j in range(len(sample_names)):
    selected_mt = sample_test.filter_cols(sample_test.s == f'{sample_names[j]}').GT.collect()[number_of_snp]
    for k in range(5):
      counts = [int(re.search(r'\d+(\.\d+)?', str(i)).group(0)) for i in table_with_freq.select(f"{pops[k]}").collect()][number_of_snp]
      res[j, :][k] += np.log(1 + counts) * selected_mt + np.log((1 + diploid) * samples_in_deme[pops[k]] - counts + 1) * (1 + diploid - selected_mt)
  else:
    return res

# %%
def prediction_naive_bayes(sample_test, counts, sample_names, number_of_snp):
  res = log_prediction_naiveBayes(sample_test, counts, sample_names, number_of_snp)
  # Вычисляем экспоненту для каждого значения в res, вычитая максимальное значение
  res = np.exp(res - np.max(res))
  # Нормализуем каждую строку так, чтобы сумма элементов в строке была равна 1
  res = res / res.sum(axis=1, keepdims=True)
  return res

# %%
def logloss_error(prediction_table):
  """
  Вычисляет logloss error для Hail Table с вероятностями.

  Args:
      prediction_table (Hail Table): Таблица, содержащая столбцы с вероятностями
          принадлежности к популяциям и столбец 'super_pop' с истинными классами.

  Returns:
      float: Значение logloss error.
  """

  # Получаем список названий популяций из колонок
  populations = ['EAS', 'SAS', 'AFR', 'EUR', 'AMR']

  # Создаем список выражений для получения вероятности для истинного класса
  probs_for_correct_classes_expr = [
    hl.if_else(prediction_table.super_pop == population,
               prediction_table[population],
               hl.literal(0))
    for population in populations
  ]

  # Вычисляем среднее логарифма вероятности для истинного класса
  logloss = - prediction_table.aggregate(hl.agg.mean(hl.log(hl.sum(probs_for_correct_classes_expr))))

  return logloss

# %%
def App_test_error(sample_test, counts, sample_names, number_of_snp, table):
    """
  Вычисляет ошибку для каждого SNP

  Args:
     sample_test - matrix table по типу vcf.gz только генотипы 0, 1, 2 - получен на 5м шаге
     counts - hail table с частотами каждого SNP в популяциях
     sample_names - имя образцов для обучающей выборки
     number_of_snp - для какого SNP считаем вероятности
     table - hail table = annotationTraining.txt

  Returns:
    Значение logloss error для каждого SNP в файле.
  """
    #Считаем матрицу вероятностей
    res = prediction_naive_bayes(sample_test, counts, sample_names, number_of_snp)
    # Преобразуем numpy массив в pandas DataFrame
    df = pd.DataFrame(res, columns=pops)
    #Добавляем колонку с именами образцов
    df["sample"] = sample_names
    #Добавляем колонку с именами популяций
    population = table.super_pop.collect()
    df["super_pop"] = population
    ht = hl.Table.from_pandas(df)
    error = logloss_error(ht)
    return error

# %%
#продолжение find next AIMs - мы получаем список error для каждого SNP
min_error = min(error)
best_snp = error.index(min_error) #находим образец с минимальной ошибкой
sample_next_AIM = sample_test.filter_cols(sample_test.s == f'{sample_names[best_snp]}').GT
#return sample_next_AIM, min_error

# %%
#Собираем функцию find AIM
for i in range(numAIM):
  best, error = find_next_AIM()

# %% [markdown]
# Отбросы кода

# %%
#log.prediction.naive.bayes
t = hl.import_table("annotationTraining.txt")
sample_test = hl.read_matrix_table('chr.mt')
table_with_freq = table.key_by()
sample_names = [(re.search(r"Struct\(sample='(.*?)'\)", str(i)).group(1)) for i in t.select("sample").collect()]
res = np.zeros((len(sample_names), demes))
for j in range(len(sample_names)):
  selected_mt = sample_test.filter_cols(sample_test.s == f'{sample_names[j]}').GT.collect()
  for k in range(5):
    counts = [int(re.search(r'\d+(\.\d+)?', str(i)).group(0)) for i in table_with_freq.select(f"{pops[k]}").collect()]
    for i in range(1):
      res[j, :][k] += np.log(1 + counts[i]) * selected_mt[i] + np.log((1 + diploid) * samples_in_deme[pops[k]] - counts[i] + 1) * (1 + diploid - selected_mt[i])
# Out:
# 2024-06-25 13:19:14.878 Hail: INFO: Reading table without type imputation
#   Loading field 'sample' as type str (not specified)
#   Loading field 'pop' as type str (not specified)
#   Loading field 'super_pop' as type str (not specified)
#   Loading field 'gender' as type str (not specified)
# 2024-06-25 13:19:16.530 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:17.088 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:17.599 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:18.088 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:18.662 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:20.652 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:20.919 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:21.185 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:21.444 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:21.709 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:23.005 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:23.247 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:23.483 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:23.726 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:24.030 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:24.901 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:25.144 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:25.802 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:26.062 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:26.305 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:27.267 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:27.502 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:27.764 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:28.022 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:28.632 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:30.156 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:30.666 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:31.024 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:31.428 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:32.476 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:34.405 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:34.894 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:35.586 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:36.120 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:37.211 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:39.152 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:39.618 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:40.093 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:40.513 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:40.984 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:43.481 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:43.792 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:44.154 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:44.420 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:44.667 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:45.568 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:46.204 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:46.521 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:46.762 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:47.076 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:49.372 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:49.593 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:49.934 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:50.172 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:50.417 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:19:51.413 Hail: INFO: Coerced sorted dataset
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-123-ac37e8e6bd2a> in <cell line: 7>()
#       8   selected_mt = sample_test.filter_cols(sample_test.s == f'{sample_names[j]}').GT.collect()
#       9   for k in range(5):
# ---> 10     counts = [int(re.search(r'\d+(\.\d+)?', str(i)).group(0)) for i in table_with_freq.select(f"{pops[k]}").collect()]
#      11     for i in range(1):
#      12       res[j, :][k] += np.log(1 + counts[i]) * selected_mt[i] + np.log((1 + diploid) * samples_in_deme[pops[k]] - counts[i] + 1) * (1 + diploid - selected_mt[i])
#
# <decorator-gen-1343> in collect(self, _localize, _timed)
#
# /usr/local/lib/python3.10/dist-packages/hail/typecheck/check.py in wrapper(__original_func, *args, **kwargs)
#     583     def wrapper(__original_func: Callable[..., T], *args, **kwargs) -> T:
#     584         args_, kwargs_ = check_all(__original_func, args, kwargs, checkers, is_method=is_method)
# --> 585         return __original_func(*args_, **kwargs_)
#     586
#     587     return wrapper
#
# /usr/local/lib/python3.10/dist-packages/hail/table.py in collect(self, _localize, _timed)
#    2815         e = construct_expr(rows_ir, hl.tarray(t.row.dtype))
#    2816         if _localize:
# -> 2817             return Env.backend().execute(e._ir, timed=_timed)
#    2818         else:
#    2819             return e
#
# /usr/local/lib/python3.10/dist-packages/hail/backend/spark_backend.py in execute(self, ir, timed)
#     216     def execute(self, ir: BaseIR, timed: bool = False) -> Any:
#     217         try:
# --> 218             return super().execute(ir, timed)
#     219         except Exception as err:
#     220             if self._copy_log_on_error:
#
# /usr/local/lib/python3.10/dist-packages/hail/backend/backend.py in execute(self, ir, timed)
#     176         payload = ExecutePayload(self._render_ir(ir), '{"name":"StreamBufferSpec"}', timed)
#     177         try:
# --> 178             result, timings = self._rpc(ActionTag.EXECUTE, payload)
#     179         except FatalError as e:
#     180             raise e.maybe_user_error(ir) from None
#
# /usr/local/lib/python3.10/dist-packages/hail/backend/py4j_backend.py in _rpc(self, action, payload)
#     216         path = action_routes[action]
#     217         port = self._backend_server_port
# --> 218         resp = self._requests_session.post(f'http://localhost:{port}{path}', data=data)
#     219         if resp.status_code >= 400:
#     220             error_json = orjson.loads(resp.content)
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     635         """
#     636
# --> 637         return self.request("POST", url, data=data, json=json, **kwargs)
#     638
#     639     def put(self, url, data=None, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#нормальный log.prediction naive bayes
t = hl.import_table("annotationTraining.txt")
sample_test = hl.read_matrix_table('chr.mt')
table_with_freq = table.key_by()
sample_names = [(re.search(r"Struct\(sample='(.*?)'\)", str(i)).group(1)) for i in t.select("sample").collect()]
res = np.zeros((len(sample_names), demes))
#Отдельно вводим число, до этой функции
number_of_snp = 3
for j in range(len(sample_names)):
  selected_mt = sample_test.filter_cols(sample_test.s == f'{sample_names[j]}').GT.collect()[number_of_snp]
  for k in range(5):
    counts = [int(re.search(r'\d+(\.\d+)?', str(i)).group(0)) for i in table_with_freq.select(f"{pops[k]}").collect()][number_of_snp]
    res[j, :][k] += np.log(1 + counts) * selected_mt + np.log((1 + diploid) * samples_in_deme[pops[k]] - counts + 1) * (1 + diploid - selected_mt)
# Out:
# 2024-06-25 13:26:36.059 Hail: INFO: Reading table without type imputation
#   Loading field 'sample' as type str (not specified)
#   Loading field 'pop' as type str (not specified)
#   Loading field 'super_pop' as type str (not specified)
#   Loading field 'gender' as type str (not specified)
# 2024-06-25 13:26:38.358 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:38.916 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:39.391 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:39.726 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:40.026 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:41.180 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:41.880 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:42.542 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:43.208 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:43.974 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:46.601 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:47.051 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:47.592 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:48.028 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:48.346 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:49.548 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:50.024 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:50.476 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:50.728 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:50.987 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:51.598 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:51.863 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:52.124 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:52.383 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:52.648 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:54.534 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:54.706 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:54.855 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:55.004 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:55.165 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:55.826 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:56.068 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:56.344 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:56.591 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:56.834 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:58.128 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:58.428 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:58.616 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:58.858 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:26:59.101 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:00.019 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:00.657 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:00.882 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:01.151 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:01.485 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:02.918 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:03.290 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:03.653 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:04.122 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:05.244 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:08.229 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:08.695 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:09.169 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:09.656 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:10.858 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:12.687 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:13.245 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:14.241 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:14.908 Hail: INFO: Coerced sorted dataset
# 2024-06-25 13:27:15.260 Hail: INFO: Coerced sorted dataset
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-130-32639618f29a> in <cell line: 9>()
#      10   selected_mt = sample_test.filter_cols(sample_test.s == f'{sample_names[j]}').GT.collect()[number_of_snp]
#      11   for k in range(5):
# ---> 12     counts = [int(re.search(r'\d+(\.\d+)?', str(i)).group(0)) for i in table_with_freq.select(f"{pops[k]}").collect()][number_of_snp]
#      13     res[j, :][k] += np.log(1 + counts) * selected_mt + np.log((1 + diploid) * samples_in_deme[pops[k]] - counts + 1) * (1 + diploid - selected_mt)
#
# <decorator-gen-1343> in collect(self, _localize, _timed)
#
# /usr/local/lib/python3.10/dist-packages/hail/typecheck/check.py in wrapper(__original_func, *args, **kwargs)
#     583     def wrapper(__original_func: Callable[..., T], *args, **kwargs) -> T:
#     584         args_, kwargs_ = check_all(__original_func, args, kwargs, checkers, is_method=is_method)
# --> 585         return __original_func(*args_, **kwargs_)
#     586
#     587     return wrapper
#
# /usr/local/lib/python3.10/dist-packages/hail/table.py in collect(self, _localize, _timed)
#    2815         e = construct_expr(rows_ir, hl.tarray(t.row.dtype))
#    2816         if _localize:
# -> 2817             return Env.backend().execute(e._ir, timed=_timed)
#    2818         else:
#    2819             return e
#
# /usr/local/lib/python3.10/dist-packages/hail/backend/spark_backend.py in execute(self, ir, timed)
#     216     def execute(self, ir: BaseIR, timed: bool = False) -> Any:
#     217         try:
# --> 218             return super().execute(ir, timed)
#     219         except Exception as err:
#     220             if self._copy_log_on_error:
#
# /usr/local/lib/python3.10/dist-packages/hail/backend/backend.py in execute(self, ir, timed)
#     176         payload = ExecutePayload(self._render_ir(ir), '{"name":"StreamBufferSpec"}', timed)
#     177         try:
# --> 178             result, timings = self._rpc(ActionTag.EXECUTE, payload)
#     179         except FatalError as e:
#     180             raise e.maybe_user_error(ir) from None
#
# /usr/local/lib/python3.10/dist-packages/hail/backend/py4j_backend.py in _rpc(self, action, payload)
#     216         path = action_routes[action]
#     217         port = self._backend_server_port
# --> 218         resp = self._requests_session.post(f'http://localhost:{port}{path}', data=data)
#     219         if resp.status_code >= 400:
#     220             error_json = orjson.loads(resp.content)
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     635         """
#     636
# --> 637         return self.request("POST", url, data=data, json=json, **kwargs)
#     638
#     639     def put(self, url, data=None, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# KeyboardInterrupt:
